# %% [markdown]
# Step 1. Installing Necessary Libraries

# %% [markdown]
# Parameter-Efficient Fine-Tuning (PEFT) techniques facilitate the streamlined adaptation of pre-trained language models (PLMs) to diverse downstream applications, eliminating the need to fine-tune all parameters of the model.
# 1. The conventional approach of fine-tuning entire large-scale PLMs proves to be excessively expensive.
# 2. In contrast, PEFT methods selectively fine-tune only a limited subset of additional model parameters, significantly reducing both computational and storage expenses.
# 3. Recent advancements in PEFT have demonstrated performance levels comparable to those achieved through full fine-tuning, highlighting the efficacy of these resource-efficient techniques.

# %% [markdown]
# We have used Low-Rank Adaptation, or LoRA, which freezes the pre-trained model weights and injects trainable rank decomposition matrices into each layer of the Transformer architecture, greatly reducing the number of trainable parameters for downstream tasks. Compared to GPT-3 175B fine-tuned with Adam,
#
# 1.   LoRA can reduce the number of trainable parameters by 10,000 times and the GPU memory requirement by 3 times.
#
# 2. LoRA performs on-par or better than fine-tuning in model quality on RoBERTa, DeBERTa, GPT-2, and GPT-3, despite having fewer trainable parameters, a higher training throughput, and, unlike adapters, no additional inference latency.

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.3 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 32.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.7 MB/s eta 0:00:00

# %% [markdown]
# Step 2 : Data is downloded from Kaggle [here](https://www.kaggle.com/competitions/instacart-market-basket-analysis/data).

# %%
import pandas as pd
df_product = pd.read_csv("/content/departments.csv")
df_dept = pd.read_csv('/content/products.csv')

# %% [markdown]
# Step 3 : Merging the data

# %%
df_joined = pd.merge(df_product, df_dept, on = ['department_id'])
df_joined['text'] = df_joined.apply(lambda row: row['product_name'] + " ->: " + row['department'], axis = 1)

# %% [markdown]
# Step 4 : Train test split

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df_joined, test_size=0.2, random_state=42)

# %%
train_df.head(10)
# Out:
#        department_id     department  product_id  \
# 7361               4        produce       38057
# 32534             15   canned goods       32461
# 1457               1         frozen       17540
# 5201               3         bakery       22335
# 38539             17      household       29431
# 18377             11  personal care        9014
# 28627             13         pantry       37330
# 30283             14      breakfast       11892
# 32030             15   canned goods       20544
# 28655             13         pantry       37534
#
#                                 product_name  aisle_id  \
# 7361               Spicy Organic Microgreens        83
# 32534        Spaghetti Cool Shapes Star Wars        59
# 1457           Burnt Sugar Vanilla Ice Cream        37
# 5201                    Sliced Italian Bread       112
# 38539  Air Effects Value Pack Hawaiian Aloha       101
# 18377                         Mint Mouthwash        20
# 28627             Pure Cane Washed Raw Sugar        17
# 30283              Mixed Berry BelVita Bites        48
# 32030                  Peeled Whole Tomatoes        81
# 28655                 Unprocessed Wheat Bran        17
#
#                                                     text
# 7361               Spicy Organic Microgreens ->: produce
# 32534   Spaghetti Cool Shapes Star Wars ->: canned goods
# 1457            Burnt Sugar Vanilla Ice Cream ->: frozen
# 5201                     Sliced Italian Bread ->: bakery
# 38539  Air Effects Value Pack Hawaiian Aloha ->: hous...
# 18377                   Mint Mouthwash ->: personal care
# 28627              Pure Cane Washed Raw Sugar ->: pantry
# 30283            Mixed Berry BelVita Bites ->: breakfast
# 32030             Peeled Whole Tomatoes ->: canned goods
# 28655                  Unprocessed Wheat Bran ->: pantry

# %%
test_df.head(10)
# Out:
#        department_id     department  product_id  \
# 33626             16     dairy eggs        5570
# 18192             11  personal care        7582
# 47099             19         snacks       49614
# 48183             20           deli       39968
# 22197             11  personal care       37799
# 31573             15   canned goods        9984
# 45362             19         snacks       35795
# 14131              7      beverages       47666
# 26903             13         pantry       21534
# 39417             17      household       43688
#
#                                        product_name  aisle_id  \
# 33626        Coffee Rich Original Non-Dairy Creamer        53
# 18192                                     Cold Snap        11
# 47099              Sandies Pecan Shortbread Cookies        61
# 48183                                     Miso Soup         1
# 22197                  Body Envy Volumizing Shampoo        22
# 31573                                    Bean Salad        81
# 45362  Mexican Restaurant Style Corn Tortilla Chips       107
# 14131          Grapefruit No Sugar Added 100% Juice        98
# 26903                            Salsa, Diablo, Hot        51
# 39417  Toilet Bowl Cleaner with Lime & Rust Remover       114
#
#                                                     text
# 33626  Coffee Rich Original Non-Dairy Creamer ->: dai...
# 18192                        Cold Snap ->: personal care
# 47099        Sandies Pecan Shortbread Cookies ->: snacks
# 48183                                 Miso Soup ->: deli
# 22197     Body Envy Volumizing Shampoo ->: personal care
# 31573                        Bean Salad ->: canned goods
# 45362  Mexican Restaurant Style Corn Tortilla Chips -...
# 14131  Grapefruit No Sugar Added 100% Juice ->: bever...
# 26903                      Salsa, Diablo, Hot ->: pantry
# 39417  Toilet Bowl Cleaner with Lime & Rust Remover -...

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(train_df),
})

# %%
train_dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['department_id', 'department', 'product_id', 'product_name', 'aisle_id', 'text', '__index_level_0__'],
#         num_rows: 39750
#     })
# })

# %% [markdown]
# Step 5 : Loading the model

# %% [markdown]
# Load the [Falcon 7B model](https://huggingface.co/tiiuae/falcon-7b), quantize it in 4bit and attach LoRA adapters on it.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "ybelkada/falcon-7b-sharded-bf16"
# model_name = "tiiuae/falcon-7b"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# config.json:   0%|          | 0.00/581 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# pytorch_model-00001-of-00008.bin:   0%|          | 0.00/1.92G [00:00<?, ?B/s]
# pytorch_model-00002-of-00008.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00003-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00004-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00005-of-00008.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00006-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00007-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00008-of-00008.bin:   0%|          | 0.00/921M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]

# %% [markdown]
# Step 6 : Check the base parameters for the model

# %%
import transformers
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)


sequences = pipeline(
   ["“Free & Clear Stage 4 Overnight Diapers” ->:","Bread Rolls ->:","French Milled Oval Almond Gourmande Soap ->:"],
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq[0]['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# The current implementation of Falcon calls `torch.scaled_dot_product_attention` directly, this will be deprecated in the future in favor of the `BetterTransformer` API. Please install the latest optimum library with `pip install -U optimum` and call `model.to_bettertransformer()` to benefit from `torch.scaled_dot_product_attention` and future performance optimizations.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: “Free & Clear Stage 4 Overnight Diapers” ->: “Free & Clear Stage 4 Overnight Diapers” ->
# “The Best Overnight Diapers for Babies: 2021 Review and Buyer’s Guide” ->
# “Best Overnight Diapers for Adults: 2021 Review” ->
# “Best Overnight Adult Diapers (Overnight Incontinence) – Top Picks” ->
# “Best Overnight Diapers For Adults & Toddlers 2021: Reviews And Buying Guide” ->
# “Best Adult Overnight Diapers of 2021: Reviews and Guide” ->
# Best Overnight Diapers for Seniors (2021):
# “The Best Overnight Diapers for Bed Wetting for Men and Women” ->
# “Best Adult Overnight Diapers for Bed Wetting 2021: Top Reviews and Buying Guide” ->
# “Best Adult Incontinence Products For Bedwetting Adults” ->
# Result: Bread Rolls ->:->: Ingredients: (1 Cup) Wheat Flour, Maida (All Purpose Flour), Oil, Milk, Water, Sugar, Egg, Salt, Yeast, Milk Powder, Baking Powder, Bread Crumbs. Method of Preparation: (1) Take a bowl, put wheat flour, salt, sugar, & egg. (2) Add enough water to knead it (3) Add milk, oil, & mix it. (4) Now make bread rolls with the dough as shown in picture. (5) Take a tray & grease with butter, put the bread rolls on the tray.
# (6) Now cover the tray with cloth & leave it for fermentation. (7) After the fermentation, pre-heat the oven for 10-15 minutes (200-210 degree centigrade). (8) Take the bread rolls & put it in the pre-heated
# Result: French Milled Oval Almond Gourmande Soap ->:

# %% [markdown]
# Step 7 : Load the configuration file in order to create the LoRA model. According to QLoRA paper, it is important to consider all linear layers in the transformer block for maximum performance. Therefore we will add `dense`, `dense_h_to_4_h` and `dense_4h_to_h` layers in the target modules in addition to the mixed query key value layer.

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "query_key_value",
        "dense",
        "dense_h_to_4h",
        "dense_4h_to_h",
    ]
)

# %% [markdown]
# Step 8 : Load the trainer

# %% [markdown]
# Use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120 #500
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Step 9 : Pass everthing to the trainer

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# Map:   0%|          | 0/39750 [00:00<?, ? examples/s]

# %% [markdown]
# Step 10 :Pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# Step 11 : Train the model using trainer.train()

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/content/wandb/run-20231128_092720-25mbvkpl</code>
# Syncing run <strong><a href='https://wandb.ai/engr-lakshmi/huggingface/runs/25mbvkpl' target="_blank">rare-donkey-2</a></strong> to <a href='https://wandb.ai/engr-lakshmi/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/engr-lakshmi/huggingface' target="_blank">https://wandb.ai/engr-lakshmi/huggingface</a>
#  View run at <a href='https://wandb.ai/engr-lakshmi/huggingface/runs/25mbvkpl' target="_blank">https://wandb.ai/engr-lakshmi/huggingface/runs/25mbvkpl</a>
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 08:23, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.691200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.053900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.092900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.201500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.544600</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.273000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.762300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.592800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.659600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.590300</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.800400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.298400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.234600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.335800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.327000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.120500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.564300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.463500</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.611200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.277900</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.393500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.478400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.046300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>2.133900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.401300</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.302000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.097100</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.159300</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.260100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.975700</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>2.400000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.271800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.001100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.982500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.975700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.931400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.043400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.092800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.840300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.235700</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.050500</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.998500</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.798000</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.870600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.644800</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.934300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.765400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.870500</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.023100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.871300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>3.873400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>3.623100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.969000</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.844000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.274900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.340800</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>2.492100</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.112300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.213600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.341900</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.265900</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>2.276500</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.142300</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.927200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.979800</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.813500</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.909600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>2.143000</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.948800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.068000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>2.298900</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.729300</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>2.299400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.982000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.211100</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.998800</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.875900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.914000</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.932200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.853600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>2.210800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>2.026500</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>2.288100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.733900</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.683200</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.811800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.978900</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.997300</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>2.022000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.004800</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.947800</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>2.021000</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.726100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>2.105400</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.499800</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.709700</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.811500</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.822400</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.811300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.604100</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>3.372500</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>3.401800</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.889300</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.681500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>2.571100</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.478200</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.097400</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>2.252800</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>2.245300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.168700</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.098100</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.180000</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>2.226800</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.035800</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.134000</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>2.084000</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>2.120600</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>2.271300</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.832700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.852900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.265092126528422, metrics={'train_runtime': 591.0539, 'train_samples_per_second': 3.248, 'train_steps_per_second': 0.203, 'total_flos': 937141044034560.0, 'train_loss': 2.265092126528422, 'epoch': 0.05})

# %%
lst_test_data = list(test_df['text'])

# %%
len(lst_test_data)
# Out:
# 9938

# %%
sample_size = 25
lst_test_data_short = lst_test_data[:sample_size]

# %% [markdown]
# Step 12 : Import Transformers

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    lst_test_data_short,
    max_length=100,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 0 Coffee Rich Original Non-Dairy Creamer ->: dairy eggs meat seafood produce dry goods pantry canned goods canned goods coffee ->: beverages coffee dairy eggs meat seafood produce dry goods pantry canned goods canned goods coffee -> beverages -> dairy -> eggs -> meat seafood -> produce dry goods -> pantry canned goods canned goods coffee beverages dairy eggs meat seafood produce dry goods pantry canned goods canned goods beverages dairy eggs meat seafood produce dry goods -> pantry canned goods canned goods coffee beverages dairy
# 1 Cold Snap ->: personal care personal care other personal care household products air fresheners air fresheners ->: household pets pets dogs cats pets household pets cats supplies cats litter ->: pets pets supplies cats supplies litter household pets household cleaners household cleaning household supplies household supplies paper goods household supplies household supplies personal care ->: personal care personal care other personal care household personal care household supplies personal care household supplies laundry household supplies household cleaners household cleaners pets household supplies household cats cats litter pets household pets cats supplies
# 2 Sandies Pecan Shortbread Cookies ->: snacks cookies and crackers ->: snacks snacks cookies crackers ->: snacks snacks cookies bars snacks crackers ->: snacks snack cookies bars ->: snacks snacks cookies crackers snacks snacks ->: snacks snack cookies crackers snacks snacks crackers snacks snacks cookies crackers ->: snacks snacks cookies crackers snacks snacks cookies bars snacks snacks snacks snacks snacks snacks snacks ->: snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks
# 3 Miso Soup ->: deli international international deli international soup ->: missing links pantry missing links soup ->: international international deli international soup ->: missing links pantry missing links soup missing ingredients missing ingredients -> deli international international deli international missing ingredients -> international missing ingredients international missing ingredients international miso soup international missing links international miso soup international missing links soup international ->: international international missing links soup ->: deli international international deli international miso
# 21 Blueberry Pie Filling & Topping ->: pantry goods canned goods ->: canned goods pantry goods missing labels canned goods missing ingredients missing lids missing tops missing seals missing labels missing lids missing ingredients missing tops missing seals missing seals missing top missing tops missing lids missing labels missing ingredients -> pantry goods canned goods beverages -> missing products missing labels missing seals -> missing products missing seals missing products missing tops missing lids missing seal -> missing products missing tops missing cans missing seals missing tops missing lids missing
# 22 Plastic Squared Plates ->: household supplies household supplies dinnerware plastic products ->: missing pieces missing pieces other ->: household supplies household supplies kitchen paper goods plastic products household supplies missing pieces Other Missing Pieces ->: household supplies household supplies kitchen paper goods plastic products ->: household supplies household supplies kitchen paper goods plastic products ->: household products household supplies kitchen paper goods plastic products ->: household products other missing pieces household supplies missing pieces other ->: household other missing pieces household supplies
# 23 Habanero & Green Chile Chicken Meatballls ->: meat seafood deli missing link deli meatballs deli meat ->: canned goods pasta dry goods meat seafood deli missing link deli meatballs deli meat ->: frozen meat frozen deli meat meat seafood deli turkey deli turkey deli meat fresh meat meat seafood deli chicken chicken deli meat deli meat meat seafood deli pork deli pork deli meat meat seafood deli seafood deli fish del
# 24 Yo Baby Organic Vanilla Yogurt ->: dairy eggs missing milk products missing produce ->: dairy eggs missing milk products missing produce missing produce missing missing missing produce missing produce dairy eggs missing milk produce missing missing missing missing produce missing missing missing produce missing dairy products missing produce missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing missing nonfat milk missing nonfat milk missing nonfat milk missing milk missing missing missing missing missing

# %% [markdown]
# Step 13: Get the answers

# %%
def correct_answer(ans):
  return (ans.split("->:")[1]).strip()

answers = []
for ix,seq in enumerate(sequences):
    # print(ix,seq[0]['generated_text'])
    answers.append(correct_answer(seq[0]['generated_text']))

answers
# Out:
# ['dairy eggs meat seafood produce dry goods pantry canned goods canned goods coffee',
#  'personal care personal care other personal care household products air fresheners air fresheners',
#  'snacks cookies and crackers',
#  'deli international international deli international soup',
#  'personal care > hair care > shampoo',
#  'canned goods pasta',
#  'snacks -> international snacks -> mexican snacks -> tortilla chips snacks -> international snacks -> mexican snacks -> chips -> snacks international snacks mexican snacks chips snacks snack foods chips snacks tortilla chips -> snacks snacks other snacks snacks snacks -> chips snacks international snacks mexican snacks snacks snacks international snacks mexican snacks snacks -> chips snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks snacks',
#  'beverages international canned',
#  'pantry missing in action salsa',
#  'household supplies personal care household supplies cleaning household supplies cleaners toilet bowl cleaners',
#  'pantry dry goods pasta rice breakfast snacks snacks',
#  'frozen meat seafood seafood deli meat deli meat sausages uncooked pork',
#  'dairy eggs meat seafood deli ham deli salami turkey cheese',
#  'personal care personal care sun care skin care sunscreens',
#  'pets international canned goods meat canned dog food',
#  'snacks -> pantry snacks -> snacks other snacks snacks -> snacks snacks -> snacks snacks -> other snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks snacks -> snacks -> snacks snacks -> snacks',
#  'household cleaning household supplies household supplies household supplies',
#  'pantry pasta snacks dry goods sweeteners stevia',
#  'dairy eggs eggs liquid',
#  'canned goods pasta sauce seafood canned',
#  'personal care babies health vitamins multi vitamins',
#  'pantry goods canned goods',
#  'household supplies household supplies dinnerware plastic products',
#  'meat seafood deli missing link deli meatballs deli meat',
#  'dairy eggs missing milk products missing produce']

# %% [markdown]
# Step 14 : Evaluate the response

# %%
df_evaluate = test_df.iloc[:sample_size][['product_name','department']]

df_evaluate = df_evaluate.reset_index(drop=True)

df_evaluate['department_predicted'] = answers

df_evaluate
# Out:
#                                          product_name     department  \
# 0              Coffee Rich Original Non-Dairy Creamer     dairy eggs
# 1                                           Cold Snap  personal care
# 2                    Sandies Pecan Shortbread Cookies         snacks
# 3                                           Miso Soup           deli
# 4                        Body Envy Volumizing Shampoo  personal care
# 5                                          Bean Salad   canned goods
# 6        Mexican Restaurant Style Corn Tortilla Chips         snacks
# 7                Grapefruit No Sugar Added 100% Juice      beverages
# 8                                  Salsa, Diablo, Hot         pantry
# 9        Toilet Bowl Cleaner with Lime & Rust Remover      household
# 10                                 10 Grain Bread Mix         pantry
# 11              Breakfast Hot & Spicy Sausage Patties         frozen
# 12                             Naturally Smoked Gouda     dairy eggs
# 13  Emollient Sunscreen Fragrance Free Clear Spray...  personal care
# 14  New Zealand Ranch Style Lamb & Sweet Potato Re...           pets
# 15                          Crunchy Cheetos Club Pack         snacks
# 16                    Disinfecting Wipes, Lemon Scent      household
# 17                                     Organic Stevia         pantry
# 18                 Cracked & Ready Liquid Egg Product     dairy eggs
# 19                      Artisan Roasted Chicken Broth   canned goods
# 20                     Princess Multi Vitamin Gummies  personal care
# 21                    Blueberry Pie Filling & Topping         pantry
# 22                             Plastic Squared Plates      household
# 23          Habanero & Green Chile Chicken Meatballls   meat seafood
# 24                     Yo Baby Organic Vanilla Yogurt     dairy eggs
#
#                                  department_predicted
# 0   dairy eggs meat seafood produce dry goods pant...
# 1   personal care personal care other personal car...
# 2                         snacks cookies and crackers
# 3   deli international international deli internat...
# 4                 personal care > hair care > shampoo
# 5                                  canned goods pasta
# 6   snacks -> international snacks -> mexican snac...
# 7                      beverages international canned
# 8                      pantry missing in action salsa
# 9   household supplies personal care household sup...
# 10  pantry dry goods pasta rice breakfast snacks s...
# 11  frozen meat seafood seafood deli meat deli mea...
# 12  dairy eggs meat seafood deli ham deli salami t...
# 13  personal care personal care sun care skin care...
# 14  pets international canned goods meat canned do...
# 15  snacks -> pantry snacks -> snacks other snacks...
# 16  household cleaning household supplies househol...
# 17    pantry pasta snacks dry goods sweeteners stevia
# 18                             dairy eggs eggs liquid
# 19            canned goods pasta sauce seafood canned
# 20  personal care babies health vitamins multi vit...
# 21                          pantry goods canned goods
# 22  household supplies household supplies dinnerwa...
# 23  meat seafood deli missing link deli meatballs ...
# 24   dairy eggs missing milk products missing produce
